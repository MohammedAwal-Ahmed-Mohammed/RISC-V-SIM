# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# this is the datapath to replicate for single cycle
# what objects do we have?
# THE ALU
# THE REGISTER FILE
# INSTRUCTION MEMORY
# DATA MEMORY
# THE PC
# ADDER FOR PC + 4
# ADDER FOR JUMPS
# CONTROL UNIT
# ALU CONTROL
# AND GATE
# MUX FOR DATA MEM
# MUX FOR JUMPS AND BRANCH
# MUX FOR ALU
# IMMEDIATE GENERATOR (SIGN EXTENDED)
# SHIFTER

# %% [markdown]
# 1. we'll create all these as classes
# 2. we'll create like a bigger class that is made up of all these elements.. and create an instance of it when the program starts.

# %%
so we have implemented the operation that require the ALU. 
that'll be it on the ALU for now. 
we'll move to other elements

# %% [markdown]
# writing the code for the register file now.
# ![image.png](attachment:image.png)

# %% [markdown]
# still in the early but making many changes already.
# working on the device level. modelling the datapath device by device.
# each device is simplified to inputs, signals and outputs.
#
# we define the inputs, signals, and the outputs.
# then we define the methods that set them
#
# next time we code, we will include the signls in the already created classes.
